# %%
# !which python
# Out:
# /Users/ryaneudy/Documents/Workspace/neural-networks-and-deep-learning/venv/bin/python

# %%
from sklearn.datasets import load_sample_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e4c25ee0671a> in <module>
# ----> 1 from sklearn.datasets import load_sample_image
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# ...
#      |████████████████████████████████| 7.4 MB 4.1 MB/s eta 0:00:01
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
# ...

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 5.8 MB/s eta 0:00:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.3.3
#     Uninstalling pip-20.3.3:
#       Successfully uninstalled pip-20.3.3
# ...

# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# ...
#   Using cached scikit-learn-0.24.1.tar.gz (7.4 MB)
#   Installing build dependencies ... error
#   ERROR: Command errored out with exit status 1:
# ...
